# %% [markdown]
# # Таблица греческих букв. **Tex**
# ## Таблица греческих букв. **Tex**
# ### Таблица греческих букв. **Tex**
#
#
# \begin{array}{ccc}
# \text{Заглавная}&\text{Cтрочная}&\text{Название}\\
# 1) \text{Α}&{\alpha}&Альфа\\
# 2) \text{Β}&{\beta}&Бета (вита)\\
# 3) \text{Γ}&{\gamma}&Гамма \\
# 4) \text{Δ}&{\delta}&Дельта \\
# 5) \text{Ε}&{\epsilon}&Эпсилон \\
# 6) \text{Ζ}&{\zeta}&Дзета (зита) \\
# 7) \text{Η}&{\eta}&Эта (ита) \\
# 8) \text{Θ}&{\theta}&Тета (фита)\\
# 9) \text{Ι}&{\iota}&Йота\\
# 10) \text{Κ}&{\kappa}&Каппа   \\
# 11) \text{Λ}&{\lambda}&Лямбда (лямда) \\
# 12) \text{M}&{\mu}&Мю (ми) \\
# 13) \text{Ν}&{\nu}&Ню (ни)  \\
# 14) \text{Ξ}&{\xi}&Кси  \\
# 15) \text{O}&{\omicron}&Омикрон \\
# 16) \text{Π}&{\pi}&Пи  \\
# 17) \text{Ρ}&{\rho}&Ро   \\
# 18) \text{Σ}&{\sigma}&Сигма   \\
# 19) \text{Τ}&{\tau}&Тау (тав)  \\
# 20) \text{Υ}&{\upsilon	}&Юпсилон   \\
# 21) \text{Φ}&{\phi}&Фи  \\
# 22) \text{Χ}&{\chi}&Хи   \\
# 23) \text{Ψ}&{\psi}&Пси   \\
# 24) \text{Ω}&{\omega}&Омега  \\
#  \end{array}
#
# \\
# Формула нормального распределения
# $$f(x)=\frac{1}{\sigma\sqrt{2\pi}}e^\left(-\frac{(x-\mu)^2}{2\sigma^2}\right)$$
